# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayush-Gole8/DeepFake/blob/main/23102A0005_DL_Lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np

# %%
(X_train, y_train), (X_test, y_test) = datasets.cifar10.load_data()

# %%
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
class_names = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck']
plt.figure(figsize=(10,10))
for i in range(16):
    plt.subplot(4,4,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i])
    plt.xlabel(class_names[np.argmax(y_train[i])])
plt.show()

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(32,32,3)))
model.add(layers.Conv2D(32, (3,3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Dropout(0.25))
model.add(layers.Conv2D(64, (3,3), activation='relu', padding='same'))
model.add(layers.Conv2D(64, (3,3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Dropout(0.25))
model.add(layers.Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(layers.Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Dropout(0.25))
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='gelu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(10, activation='softmax'))
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=[
        'accuracy',
        tf.keras.metrics.AUC(name='auc'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.TopKCategoricalAccuracy(k=3, name='top_3_accuracy')
    ]
)
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_18 (Conv2D)              │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_21 (Conv2D)              │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_22 (Conv2D)              │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_23 (Conv2D)              │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,341,226 (5.12 MB)
#  Trainable params: 1,341,226 (5.12 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train, y_train,epochs=40,batch_size=32,validation_split=0.2)
# Out:
# Epoch 1/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.3939 - auc: 0.8410 - loss: 1.6309 - precision: 0.6471 - recall: 0.1649 - top_3_accuracy: 0.7304 - val_accuracy: 0.5394 - val_auc: 0.9091 - val_loss: 1.2675 - val_precision: 0.7333 - val_recall: 0.3215 - val_top_3_accuracy: 0.8446
# Epoch 2/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.5628 - auc: 0.9152 - loss: 1.2189 - precision: 0.7292 - recall: 0.3938 - top_3_accuracy: 0.8534 - val_accuracy: 0.6396 - val_auc: 0.9416 - val_loss: 1.0134 - val_precision: 0.7867 - val_recall: 0.4999 - val_top_3_accuracy: 0.8920
# Epoch 3/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.6254 - auc: 0.9370 - loss: 1.0507 - precision: 0.7633 - recall: 0.4918 - top_3_accuracy: 0.8869 - val_accuracy: 0.6529 - val_auc: 0.9481 - val_loss: 0.9650 - val_precision: 0.8051 - val_recall: 0.5067 - val_top_3_accuracy: 0.9014
# Epoch 4/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.6644 - auc: 0.9482 - loss: 0.9516 - precision: 0.7829 - recall: 0.5474 - top_3_accuracy: 0.9058 - val_accuracy: 0.6921 - val_auc: 0.9550 - val_loss: 0.8822 - val_precision: 0.7956 - val_recall: 0.5875 - val_top_3_accuracy: 0.9161
# Epoch 5/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.6871 - auc: 0.9555 - loss: 0.8810 - precision: 0.7928 - recall: 0.5849 - top_3_accuracy: 0.9179 - val_accuracy: 0.7176 - val_auc: 0.9631 - val_loss: 0.7990 - val_precision: 0.8212 - val_recall: 0.6222 - val_top_3_accuracy: 0.9275
# Epoch 6/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.7075 - auc: 0.9603 - loss: 0.8289 - precision: 0.8068 - recall: 0.6129 - top_3_accuracy: 0.9242 - val_accuracy: 0.7402 - val_auc: 0.9678 - val_loss: 0.7446 - val_precision: 0.8330 - val_recall: 0.6459 - val_top_3_accuracy: 0.9349
# Epoch 7/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.7219 - auc: 0.9642 - loss: 0.7854 - precision: 0.8150 - recall: 0.6373 - top_3_accuracy: 0.9319 - val_accuracy: 0.7423 - val_auc: 0.9675 - val_loss: 0.7412 - val_precision: 0.8318 - val_recall: 0.6552 - val_top_3_accuracy: 0.9378
# Epoch 8/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.7338 - auc: 0.9669 - loss: 0.7519 - precision: 0.8186 - recall: 0.6539 - top_3_accuracy: 0.9373 - val_accuracy: 0.7501 - val_auc: 0.9683 - val_loss: 0.7306 - val_precision: 0.8276 - val_recall: 0.6822 - val_top_3_accuracy: 0.9416
# Epoch 9/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.7440 - auc: 0.9691 - loss: 0.7262 - precision: 0.8239 - recall: 0.6668 - top_3_accuracy: 0.9414 - val_accuracy: 0.7640 - val_auc: 0.9720 - val_loss: 0.6877 - val_precision: 0.8493 - val_recall: 0.6785 - val_top_3_accuracy: 0.9414
# Epoch 10/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.7522 - auc: 0.9713 - loss: 0.6997 - precision: 0.8287 - recall: 0.6805 - top_3_accuracy: 0.9460 - val_accuracy: 0.7631 - val_auc: 0.9718 - val_loss: 0.6831 - val_precision: 0.8340 - val_recall: 0.7032 - val_top_3_accuracy: 0.9453
# Epoch 11/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.7595 - auc: 0.9720 - loss: 0.6875 - precision: 0.8336 - recall: 0.6891 - top_3_accuracy: 0.9464 - val_accuracy: 0.7671 - val_auc: 0.9708 - val_loss: 0.6921 - val_precision: 0.8353 - val_recall: 0.7116 - val_top_3_accuracy: 0.9420
# Epoch 12/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.7669 - auc: 0.9744 - loss: 0.6561 - precision: 0.8378 - recall: 0.7021 - top_3_accuracy: 0.9510 - val_accuracy: 0.7751 - val_auc: 0.9740 - val_loss: 0.6516 - val_precision: 0.8438 - val_recall: 0.7155 - val_top_3_accuracy: 0.9485
# Epoch 13/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.7729 - auc: 0.9752 - loss: 0.6436 - precision: 0.8407 - recall: 0.7085 - top_3_accuracy: 0.9523 - val_accuracy: 0.7761 - val_auc: 0.9745 - val_loss: 0.6490 - val_precision: 0.8444 - val_recall: 0.7139 - val_top_3_accuracy: 0.9499
# Epoch 14/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.7756 - auc: 0.9757 - loss: 0.6337 - precision: 0.8436 - recall: 0.7164 - top_3_accuracy: 0.9540 - val_accuracy: 0.7705 - val_auc: 0.9709 - val_loss: 0.6865 - val_precision: 0.8368 - val_recall: 0.7090 - val_top_3_accuracy: 0.9444
# Epoch 15/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.7827 - auc: 0.9768 - loss: 0.6195 - precision: 0.8451 - recall: 0.7228 - top_3_accuracy: 0.9558 - val_accuracy: 0.7507 - val_auc: 0.9691 - val_loss: 0.7204 - val_precision: 0.8365 - val_recall: 0.6792 - val_top_3_accuracy: 0.9381
# Epoch 16/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.7866 - auc: 0.9775 - loss: 0.6113 - precision: 0.8488 - recall: 0.7272 - top_3_accuracy: 0.9555 - val_accuracy: 0.7734 - val_auc: 0.9740 - val_loss: 0.6579 - val_precision: 0.8486 - val_recall: 0.7095 - val_top_3_accuracy: 0.9472
# Epoch 17/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.7911 - auc: 0.9782 - loss: 0.5975 - precision: 0.8530 - recall: 0.7345 - top_3_accuracy: 0.9586 - val_accuracy: 0.7805 - val_auc: 0.9749 - val_loss: 0.6460 - val_precision: 0.8544 - val_recall: 0.7103 - val_top_3_accuracy: 0.9489
# Epoch 18/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.7921 - auc: 0.9789 - loss: 0.5888 - precision: 0.8535 - recall: 0.7382 - top_3_accuracy: 0.9596 - val_accuracy: 0.7810 - val_auc: 0.9728 - val_loss: 0.6654 - val_precision: 0.8433 - val_recall: 0.7310 - val_top_3_accuracy: 0.9449
# Epoch 19/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.7957 - auc: 0.9794 - loss: 0.5810 - precision: 0.8539 - recall: 0.7433 - top_3_accuracy: 0.9610 - val_accuracy: 0.7818 - val_auc: 0.9740 - val_loss: 0.6460 - val_precision: 0.8480 - val_recall: 0.7274 - val_top_3_accuracy: 0.9485
# Epoch 20/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.7954 - auc: 0.9792 - loss: 0.5838 - precision: 0.8555 - recall: 0.7416 - top_3_accuracy: 0.9603 - val_accuracy: 0.7798 - val_auc: 0.9733 - val_loss: 0.6613 - val_precision: 0.8338 - val_recall: 0.7371 - val_top_3_accuracy: 0.9515
# Epoch 21/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8009 - auc: 0.9800 - loss: 0.5729 - precision: 0.8563 - recall: 0.7482 - top_3_accuracy: 0.9614 - val_accuracy: 0.7856 - val_auc: 0.9730 - val_loss: 0.6576 - val_precision: 0.8437 - val_recall: 0.7335 - val_top_3_accuracy: 0.9496
# Epoch 22/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8027 - auc: 0.9804 - loss: 0.5627 - precision: 0.8568 - recall: 0.7516 - top_3_accuracy: 0.9631 - val_accuracy: 0.7911 - val_auc: 0.9756 - val_loss: 0.6263 - val_precision: 0.8498 - val_recall: 0.7418 - val_top_3_accuracy: 0.9505
# Epoch 23/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8077 - auc: 0.9807 - loss: 0.5563 - precision: 0.8613 - recall: 0.7574 - top_3_accuracy: 0.9639 - val_accuracy: 0.7803 - val_auc: 0.9745 - val_loss: 0.6438 - val_precision: 0.8447 - val_recall: 0.7227 - val_top_3_accuracy: 0.9491
# Epoch 24/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8074 - auc: 0.9808 - loss: 0.5556 - precision: 0.8600 - recall: 0.7579 - top_3_accuracy: 0.9641 - val_accuracy: 0.7775 - val_auc: 0.9722 - val_loss: 0.6713 - val_precision: 0.8323 - val_recall: 0.7331 - val_top_3_accuracy: 0.9462
# Epoch 25/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8098 - auc: 0.9814 - loss: 0.5467 - precision: 0.8613 - recall: 0.7611 - top_3_accuracy: 0.9651 - val_accuracy: 0.7801 - val_auc: 0.9729 - val_loss: 0.6640 - val_precision: 0.8394 - val_recall: 0.7299 - val_top_3_accuracy: 0.9474
# Epoch 26/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8091 - auc: 0.9814 - loss: 0.5471 - precision: 0.8623 - recall: 0.7602 - top_3_accuracy: 0.9647 - val_accuracy: 0.7878 - val_auc: 0.9757 - val_loss: 0.6296 - val_precision: 0.8474 - val_recall: 0.7358 - val_top_3_accuracy: 0.9490
# Epoch 27/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8081 - auc: 0.9812 - loss: 0.5484 - precision: 0.8610 - recall: 0.7581 - top_3_accuracy: 0.9655 - val_accuracy: 0.7827 - val_auc: 0.9726 - val_loss: 0.6632 - val_precision: 0.8388 - val_recall: 0.7327 - val_top_3_accuracy: 0.9507
# Epoch 28/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8116 - auc: 0.9814 - loss: 0.5425 - precision: 0.8652 - recall: 0.7659 - top_3_accuracy: 0.9647 - val_accuracy: 0.7826 - val_auc: 0.9716 - val_loss: 0.6756 - val_precision: 0.8391 - val_recall: 0.7363 - val_top_3_accuracy: 0.9496
# Epoch 29/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8148 - auc: 0.9817 - loss: 0.5386 - precision: 0.8652 - recall: 0.7668 - top_3_accuracy: 0.9639 - val_accuracy: 0.7849 - val_auc: 0.9734 - val_loss: 0.6546 - val_precision: 0.8438 - val_recall: 0.7381 - val_top_3_accuracy: 0.9489
# Epoch 30/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8155 - auc: 0.9824 - loss: 0.5288 - precision: 0.8626 - recall: 0.7685 - top_3_accuracy: 0.9680 - val_accuracy: 0.7950 - val_auc: 0.9752 - val_loss: 0.6227 - val_precision: 0.8487 - val_recall: 0.7494 - val_top_3_accuracy: 0.9501
# Epoch 31/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8175 - auc: 0.9825 - loss: 0.5252 - precision: 0.8649 - recall: 0.7725 - top_3_accuracy: 0.9683 - val_accuracy: 0.7786 - val_auc: 0.9716 - val_loss: 0.6809 - val_precision: 0.8407 - val_recall: 0.7301 - val_top_3_accuracy: 0.9434
# Epoch 32/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8132 - auc: 0.9824 - loss: 0.5319 - precision: 0.8639 - recall: 0.7696 - top_3_accuracy: 0.9664 - val_accuracy: 0.7908 - val_auc: 0.9744 - val_loss: 0.6380 - val_precision: 0.8456 - val_recall: 0.7455 - val_top_3_accuracy: 0.9505
# Epoch 33/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8163 - auc: 0.9820 - loss: 0.5291 - precision: 0.8648 - recall: 0.7723 - top_3_accuracy: 0.9670 - val_accuracy: 0.7917 - val_auc: 0.9756 - val_loss: 0.6251 - val_precision: 0.8477 - val_recall: 0.7468 - val_top_3_accuracy: 0.9562
# Epoch 34/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8185 - auc: 0.9829 - loss: 0.5192 - precision: 0.8660 - recall: 0.7742 - top_3_accuracy: 0.9679 - val_accuracy: 0.7880 - val_auc: 0.9720 - val_loss: 0.6733 - val_precision: 0.8371 - val_recall: 0.7497 - val_top_3_accuracy: 0.9491
# Epoch 35/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.8140 - auc: 0.9824 - loss: 0.5305 - precision: 0.8649 - recall: 0.7689 - top_3_accuracy: 0.9661 - val_accuracy: 0.7846 - val_auc: 0.9716 - val_loss: 0.6793 - val_precision: 0.8332 - val_recall: 0.7458 - val_top_3_accuracy: 0.9483
# Epoch 36/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8227 - auc: 0.9831 - loss: 0.5117 - precision: 0.8692 - recall: 0.7808 - top_3_accuracy: 0.9696 - val_accuracy: 0.7783 - val_auc: 0.9715 - val_loss: 0.6761 - val_precision: 0.8384 - val_recall: 0.7366 - val_top_3_accuracy: 0.9460
# Epoch 37/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8179 - auc: 0.9820 - loss: 0.5290 - precision: 0.8691 - recall: 0.7739 - top_3_accuracy: 0.9674 - val_accuracy: 0.7868 - val_auc: 0.9727 - val_loss: 0.6654 - val_precision: 0.8445 - val_recall: 0.7377 - val_top_3_accuracy: 0.9496
# Epoch 38/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8181 - auc: 0.9823 - loss: 0.5282 - precision: 0.8666 - recall: 0.7737 - top_3_accuracy: 0.9678 - val_accuracy: 0.7863 - val_auc: 0.9733 - val_loss: 0.6517 - val_precision: 0.8414 - val_recall: 0.7414 - val_top_3_accuracy: 0.9477
# Epoch 39/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8225 - auc: 0.9836 - loss: 0.5095 - precision: 0.8673 - recall: 0.7808 - top_3_accuracy: 0.9694 - val_accuracy: 0.7826 - val_auc: 0.9715 - val_loss: 0.6829 - val_precision: 0.8336 - val_recall: 0.7439 - val_top_3_accuracy: 0.9498
# Epoch 40/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.8205 - auc: 0.9830 - loss: 0.5176 - precision: 0.8684 - recall: 0.7769 - top_3_accuracy: 0.9685 - val_accuracy: 0.7942 - val_auc: 0.9727 - val_loss: 0.6611 - val_precision: 0.8399 - val_recall: 0.7573 - val_top_3_accuracy: 0.9529

# %%
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
def plot_predictions(index):
    img = X_test[index]
    true_label = class_names[np.argmax(y_test[index])]
    pred_probs = model.predict(np.expand_dims(img, axis=0))
    pred_label = class_names[np.argmax(pred_probs)]

    plt.imshow(img)
    plt.title(f"True: {true_label} | Pred: {pred_label}")
    plt.axis('off')
    plt.show()

for i in range(10):
    plot_predictions(i)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 526ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
